# %% [markdown]
# <a href="https://colab.research.google.com/github/Mosaraf15/Data_preprocessing_for_ML_with_Python/blob/main/04_Project_Data_Preproccessing_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04 Project Data Preproccessing with Pandas (combine Part 1, 2 & 3)
#
# #####**Md.Mosaraf Hossain Khan**
# Chittagang, Bangladesh
#
# Instructor: **Md Shahidullah Kawsar**
# <br>Data Scientist, IDARE, Houston, TX, USA
#
# #### Objectives:
# - How to extract new information from a column?
# - How to create a column based on a condition or function?
# - Removing a string from a column
# - Checking the unique values for each column
# - performing calculation in dataframe columns
# - dataframe sorting

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #### Importing the required libraries for processing

# %%
import numpy as np
import pandas as pd

# display 100 rows of the dataframe
pd.options.display.max_rows = 100

# %% [markdown]
# #### Q1: Import the ODI_cricket.xlsx file bowler datasheet in the notebook

# %%
df = pd.read_excel("/content/drive/MyDrive/Data-Science/03 Data_preprocessing_for_ML_with_Python/data_preprocessing_for_ML_with_Python-main/ODI_cricket.xlsx", sheet_name="bowler", engine="openpyxl")

# %% [markdown]
# #### Q2: Display the first 10 rows of the dataframe

# %%
display(df.head(10))
# Out:
#                          Player       Span  Mat  Inns  Balls   Runs  Wkts  \
# 0  M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811  12326   534
# 1             Wasim Akram (PAK)  1984-2003  356   351  18186  11812   502
# 2            Waqar Younis (PAK)  1989-2003  262   258  12698   9919   416
# 3          WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775  11014   400
# 4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670  13632   395
# 5       SM Pollock (Afr/ICC/SA)  1996-2008  303   297  15712   9631   393
# 6          GD McGrath (AUS/ICC)  1993-2007  250   248  12970   8391   381
# 7                   B Lee (AUS)  2000-2012  221   217  11185   8877   380
# 8               SL Malinga (SL)  2004-2019  226   220  10936   9760   338
# 9         A Kumble (Asia/INDIA)  1990-2007  271   265  14496  10412   337
#
#      Ave  Econ    SR   4   5
# 0  23.08  3.93  35.2  15  10
# 1  23.52  3.89  36.2  17   6
# 2  23.84  4.68  30.5  14  13
# 3  27.53  4.18  39.4   9   4
# 4  34.51  4.62  44.7   4   9
# 5  24.50  3.67  39.9  12   5
# 6  22.02  3.88  34.0   9   7
# 7  23.36  4.76  29.4  14   9
# 8  28.87  5.35  32.3  11   8
# 9  30.89  4.30  43.0   8   2

# %%
display(df.tail())

# %% [markdown]
# #### Q3: Create a markdown cell and explain the meaning of each column

# %% [markdown]
# |<h3>Column</h3> | <h3>Description</h3> |
# |:-|:--|
# |**Player** | player name |
# |**Span**   | Career Duration |
# |**Mat**    |number of matches played |
# |**Inns**   |number of innings bowled |
# |**Balls**  |number of balls bowled |
# |**Runs**   |total runs conceded |
# |**Wkts**   |total wickets taken |
# |**Ave⭑**   |number of runs conceded per wicket taken|
# |**Econ**   |average number of runs conceded per over bowled |
# |**SR**     |average number of balls bowled per wicket taken |
# | **4**     |4 wickets in an innings |
# |**5**      |5 wickets in an innings

# %% [markdown]
# #### Q4: Find the number of rows and columns in the dataframe

# %%
print(df.shape)

# number of rows
print("number of rows = ", df.shape[0])

# number of columns
print("number of columns = ", df.shape[1])
# Out:
# (77, 12)
# number of rows =  77
# number of columns =  12

# %% [markdown]
# #### Q5: Find the data statistics and check for the data types

# %%
display(df.describe())
# Out:
#               Mat        Inns         Balls          Runs        Wkts  \
# count   77.000000   77.000000     77.000000     77.000000   77.000000
# mean   194.402597  181.194805   8839.402597   6671.714286  233.805195
# std     82.485606   67.958393   3316.055457   2245.839029   84.406603
# min     80.000000   76.000000   4074.000000   2821.000000  151.000000
# 25%    136.000000  128.000000   6182.000000   5058.000000  173.000000
# 50%    170.000000  164.000000   8054.000000   6192.000000  199.000000
# 75%    227.000000  218.000000  10750.000000   8021.000000  272.000000
# max    463.000000  372.000000  18811.000000  13632.000000  534.000000
#
#              Ave       Econ         SR          4          5
# count  77.000000  77.000000  77.000000  77.000000  77.000000
# mean   28.958052   4.596753  37.909091   6.350649   2.870130
# std     4.826768   0.515814   6.060901   3.556929   2.530606
# min    18.680000   3.300000  26.100000   1.000000   0.000000
# 25%    24.970000   4.280000  33.000000   3.000000   1.000000
# 50%    29.290000   4.660000  37.800000   6.000000   2.000000
# 75%    31.900000   4.920000  41.400000   8.000000   4.000000
# max    44.480000   5.830000  52.500000  17.000000  13.000000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  77 non-null     object
#  1   Span    77 non-null     object
#  2   Mat     77 non-null     int64
#  3   Inns    77 non-null     int64
#  4   Balls   77 non-null     int64
#  5   Runs    77 non-null     int64
#  6   Wkts    77 non-null     int64
#  7   Ave     77 non-null     float64
#  8   Econ    77 non-null     float64
#  9   SR      77 non-null     float64
#  10  4       77 non-null     int64
#  11  5       77 non-null     int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 7.3+ KB
# None

# %%
df.isna().head()
# Out:
#    Player  Career_Duration  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 0   False            False           False           False         False
# 1   False            False           False           False         False
# 2   False            False           False           False         False
# 3   False            False           False           False         False
# 4   False            False           False           False         False
#
#    Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 0          False          False            False         False
# 1          False          False            False         False
# 2          False          False            False         False
# 3          False          False            False         False
# 4          False          False            False         False
#
#    Bowling_Strike_Rate  Four_Wickets  Five_Wickets
# 0                False         False         False
# 1                False         False         False
# 2                False         False         False
# 3                False         False         False
# 4                False         False         False

# %% [markdown]
# #### Q6: Are there any missing values in the dataset?

# %% [markdown]
# The non-null count column obtained using `df.info()` command shows $77$ for each of the column in the dataframe. Also, the total number rows is 77 obtained using `df.shape[0]`. Hence there is no missing values in the dataset.

# %% [markdown]
# #### Q7: Rename the column names appropriately

# %%
# Displaying the old column names for reference
print(df.columns)
# Out:
# Index(['Player',   'Span',    'Mat',   'Inns',  'Balls',   'Runs',   'Wkts',
#           'Ave',   'Econ',     'SR',        4,        5],
#       dtype='object')

# %%
df = df.rename(columns={'Span': 'Career_Duration',
                       'Mat': 'Matches_Played',
                       'Inns': 'Innings_Bowled',
                       'Balls': 'Balls_Bowled',
                       'Runs': 'Runs_Conceded',
                       'Wkts': 'Wickets_Taken',
                       'Ave': 'Bowling_Average',
                       'Econ': 'Economy_Rate',
                       'SR': 'Bowling_Strike_Rate',
                       4: 'Four_Wickets',
                       5: 'Five_Wickets'})

# %%
print(df.columns)
# Out:
# Index(['Player', 'Career_Duration', 'Matches_Played', 'Innings_Bowled',
#        'Balls_Bowled', 'Runs_Conceded', 'Wickets_Taken', 'Bowling_Average',
#        'Economy_Rate', 'Bowling_Strike_Rate', 'Four_Wickets', 'Five_Wickets'],
#       dtype='object')

# %% [markdown]
# #### Q8: How many players played for ICC?

# %%
# Splitting the 'Player' column into 'Player_Name' and 'Country'
df[["Player_Name", "Country"]] = df["Player"].str.split("(", expand=True)

# Dropping the 'Player' columns
df = df.drop('Player', axis=1)

# Displaying the dataframe
display(df.head())
# Out:
#   Career_Duration  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 0       1993-2011             350             341         18811
# 1       1984-2003             356             351         18186
# 2       1989-2003             262             258         12698
# 3       1994-2008             322             320         15775
# 4       1996-2015             398             372         17670
#
#    Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 0          12326            534            23.08          3.93
# 1          11812            502            23.52          3.89
# 2           9919            416            23.84          4.68
# 3          11014            400            27.53          4.18
# 4          13632            395            34.51          4.62
#
#    Bowling_Strike_Rate  Four_Wickets  Five_Wickets      Player_Name  \
# 0                 35.2            15            10  M Muralitharan
# 1                 36.2            17             6     Wasim Akram
# 2                 30.5            14            13    Waqar Younis
# 3                 39.4             9             4      WPUJC Vaas
# 4                 44.7             4             9   Shahid Afridi
#
#          Country
# 0   Asia/ICC/SL)
# 1           PAK)
# 2           PAK)
# 3       Asia/SL)
# 4  Asia/ICC/PAK)

# %%
# Remove the ")" from the 'Country' column
df['Country'] = df['Country'].str.replace(")", "")

# Rearrange the columns
new_col_sequence = ['Player_Name', 'Country', 'Career_Duration', 'Matches_Played', 'Innings_Bowled', 'Balls_Bowled',
                    'Runs_Conceded', 'Wickets_Taken', 'Bowling_Average', 'Economy_Rate', 'Bowling_Strike_Rate', 'Four_Wickets',
                   'Five_Wickets']

# Rearranging the columns
df = df[new_col_sequence]

# Displaying the dataframe
display(df.head())
# Out:
# <ipython-input-34-2b2904fa41d3>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Country'] = df['Country'].str.replace(")", "")
#        Player_Name       Country Career_Duration  Matches_Played  \
# 0  M Muralitharan    Asia/ICC/SL       1993-2011             350
# 1     Wasim Akram            PAK       1984-2003             356
# 2    Waqar Younis            PAK       1989-2003             262
# 3      WPUJC Vaas        Asia/SL       1994-2008             322
# 4   Shahid Afridi   Asia/ICC/PAK       1996-2015             398
#
#    Innings_Bowled  Balls_Bowled  Runs_Conceded  Wickets_Taken  \
# 0             341         18811          12326            534
# 1             351         18186          11812            502
# 2             258         12698           9919            416
# 3             320         15775          11014            400
# 4             372         17670          13632            395
#
#    Bowling_Average  Economy_Rate  Bowling_Strike_Rate  Four_Wickets  \
# 0            23.08          3.93                 35.2            15
# 1            23.52          3.89                 36.2            17
# 2            23.84          4.68                 30.5            14
# 3            27.53          4.18                 39.4             9
# 4            34.51          4.62                 44.7             4
#
#    Five_Wickets
# 0            10
# 1             6
# 2            13
# 3             4
# 4             9

# %%
# Defining a function to check if a player played for ICC or not
def icc_check(x):
    if "ICC" in x:
        return "Yes"
    else:
        return "No"

# %%
df['Played_for_ICC'] = df['Country'].apply(icc_check)

display(df.head())
# Out:
#        Player_Name       Country Career_Duration  Matches_Played  \
# 0  M Muralitharan    Asia/ICC/SL       1993-2011             350
# 1     Wasim Akram            PAK       1984-2003             356
# 2    Waqar Younis            PAK       1989-2003             262
# 3      WPUJC Vaas        Asia/SL       1994-2008             322
# 4   Shahid Afridi   Asia/ICC/PAK       1996-2015             398
#
#    Innings_Bowled  Balls_Bowled  Runs_Conceded  Wickets_Taken  \
# 0             341         18811          12326            534
# 1             351         18186          11812            502
# 2             258         12698           9919            416
# 3             320         15775          11014            400
# 4             372         17670          13632            395
#
#    Bowling_Average  Economy_Rate  Bowling_Strike_Rate  Four_Wickets  \
# 0            23.08          3.93                 35.2            15
# 1            23.52          3.89                 36.2            17
# 2            23.84          4.68                 30.5            14
# 3            27.53          4.18                 39.4             9
# 4            34.51          4.62                 44.7             4
#
#    Five_Wickets Played_for_ICC
# 0            10            Yes
# 1             6             No
# 2            13             No
# 3             4             No
# 4             9            Yes

# %%
df['Played_for_ICC'].value_counts()
# Out:
# No     64
# Yes    13
# Name: Played_for_ICC, dtype: int64

# %%
df['Played_for_ICC'].value_counts()['Yes']
# Out:
# 13

# %%
print("Number of players played for ICC =", df['Played_for_ICC'].value_counts()['Yes'])
# Out:
# Number of players played for ICC = 13

# %%
#print(f"Number of players played for ICC = {df['Played_for_ICC'].value_counts()['Yes']}")

# %% [markdown]
# #### Q9: How many different countries are present in this dataset?

# %%
# Checking how many variations are present in the country column
df['Country'].value_counts()
# Out:
# INDIA           9
# PAK             9
# AUS             8
# NZ              6
# SL              5
# WI              5
# Asia/INDIA      4
# ENG             4
# Asia/SL         3
# SA              3
# Afr/ICC/SA      2
# AUS/ICC         2
# Asia/ICC/PAK    2
# ENG/ICC         2
# ICC/NZ          2
# BAN             2
# Afr/SA          2
# ICC/WI          1
# Asia/ICC/SL     1
# Afr/ZIM         1
# ICC/SA          1
# Asia/PAK        1
# Asia/BAN        1
# AFG             1
# Name: Country, dtype: int64

# %%
df['Country'] = df['Country'].str.replace("Asia/", "")
df['Country'] = df['Country'].str.replace("Afr/", "")
df['Country'] = df['Country'].str.replace("ICC/", "")
df['Country'] = df['Country'].str.replace("/ICC", "")

display(df.head())
# Out:
#        Player_Name Country Career_Duration  Matches_Played  Innings_Bowled  \
# 0  M Muralitharan       SL       1993-2011             350             341
# 1     Wasim Akram      PAK       1984-2003             356             351
# 2    Waqar Younis      PAK       1989-2003             262             258
# 3      WPUJC Vaas       SL       1994-2008             322             320
# 4   Shahid Afridi      PAK       1996-2015             398             372
#
#    Balls_Bowled  Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 0         18811          12326            534            23.08          3.93
# 1         18186          11812            502            23.52          3.89
# 2         12698           9919            416            23.84          4.68
# 3         15775          11014            400            27.53          4.18
# 4         17670          13632            395            34.51          4.62
#
#    Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC
# 0                 35.2            15            10            Yes
# 1                 36.2            17             6             No
# 2                 30.5            14            13             No
# 3                 39.4             9             4             No
# 4                 44.7             4             9            Yes

# %%
df['Country'].value_counts()
# Out:
# INDIA    13
# PAK      12
# AUS      10
# SL        9
# SA        8
# NZ        8
# ENG       6
# WI        6
# BAN       3
# ZIM       1
# AFG       1
# Name: Country, dtype: int64

# %%
len(df['Country'].value_counts())
# Out:
# 11

# %%
print("Number of unique countries in the dataset =", len(df['Country'].unique()))
# Out:
# Number of unique countries in the dataset = 11

# %% [markdown]
# #### Q10: Which player(s) had played for the longest period of time?

# %%
# Defining two new columns 'Start_Year' and 'End_Year'
df[['Start_Year', 'End_Year']] = df['Career_Duration'].str.split('-', expand=True)

# Dropping the 'Playing_Span' column from the dataset
df = df.drop("Career_Duration", axis=1)

display(df.head())
# Out:
#        Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 0  M Muralitharan       SL             350             341         18811
# 1     Wasim Akram      PAK             356             351         18186
# 2    Waqar Younis      PAK             262             258         12698
# 3      WPUJC Vaas       SL             322             320         15775
# 4   Shahid Afridi      PAK             398             372         17670
#
#    Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 0          12326            534            23.08          3.93
# 1          11812            502            23.52          3.89
# 2           9919            416            23.84          4.68
# 3          11014            400            27.53          4.18
# 4          13632            395            34.51          4.62
#
#    Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC Start_Year  \
# 0                 35.2            15            10            Yes       1993
# 1                 36.2            17             6             No       1984
# 2                 30.5            14            13             No       1989
# 3                 39.4             9             4             No       1994
# 4                 44.7             4             9            Yes       1996
#
#   End_Year
# 0     2011
# 1     2003
# 2     2003
# 3     2008
# 4     2015

# %%
# Converting the data type of 'Start_Year' and 'End_Year' column
df['Start_Year'] = df['Start_Year'].astype('int')
df['End_Year'] = df['End_Year'].astype('int')

# Creating new column 'Years_Played'
df['Years_Played'] = (df['End_Year'] - df['Start_Year']) + 1

# Dropping the columns 'Start_Year' and 'End_Year'
df = df.drop(['Start_Year', 'End_Year'], axis=1)

display(df.head())
# Out:
#        Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 0  M Muralitharan       SL             350             341         18811
# 1     Wasim Akram      PAK             356             351         18186
# 2    Waqar Younis      PAK             262             258         12698
# 3      WPUJC Vaas       SL             322             320         15775
# 4   Shahid Afridi      PAK             398             372         17670
#
#    Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 0          12326            534            23.08          3.93
# 1          11812            502            23.52          3.89
# 2           9919            416            23.84          4.68
# 3          11014            400            27.53          4.18
# 4          13632            395            34.51          4.62
#
#    Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 0                 35.2            15            10            Yes
# 1                 36.2            17             6             No
# 2                 30.5            14            13             No
# 3                 39.4             9             4             No
# 4                 44.7             4             9            Yes
#
#    Years_Played
# 0            19
# 1            20
# 2            15
# 3            15
# 4            20

# %%
df.sort_values(by='Years_Played', ascending=False).head(5)
# Out:
#        Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 72   SR Tendulkar    INDIA             463             270          8054
# 10  ST Jayasuriya       SL             445             368         14874
# 66   Shoaib Malik      PAK             287             217          7958
# 62       CH Gayle       WI             301             199          7424
# 4   Shahid Afridi      PAK             398             372         17670
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 72           6850            154            44.48          5.10
# 10          11871            323            36.75          4.78
# 66           6192            158            39.18          4.66
# 62           5926            167            35.48          4.78
# 4           13632            395            34.51          4.62
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 72                 52.2             4             2             No
# 10                 46.0             8             4             No
# 66                 50.3             1             0             No
# 62                 44.4             3             1            Yes
# 4                  44.7             4             9            Yes
#
#     Years_Played
# 72            24
# 10            23
# 66            21
# 62            21
# 4             20

# %%
df[df['Years_Played']==df['Years_Played'].max()]
# Out:
#       Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 72  SR Tendulkar    INDIA             463             270          8054
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 72           6850            154            44.48           5.1
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 72                 52.2             4             2             No
#
#     Years_Played
# 72            24

# %% [markdown]
# <font color="green"><b>SR Tendulkar played for the longest period of time.</b></font>

# %% [markdown]
# #### Q11: Which player(s) had played for the shortest period of time?

# %%
df.sort_values(by='Years_Played', ascending=True).head(5)
# Out:
#      Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 40   BKV Prasad    INDIA             161             160          8129
# 74  Rashid Khan      AFG              80              76          4074
# 73   BAW Mendis       SL              87              84          4154
# 49  Saeed Ajmal      PAK             113             112          6000
# 44   L Klusener       SA             171             164          7336
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 40           6332            196            32.30          4.67
# 74           2821            151            18.68          4.15
# 73           3324            152            21.86          4.80
# 49           4182            184            22.72          4.18
# 44           5751            192            29.95          4.70
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 40                 41.4             3             1             No
# 74                 26.9             5             4             No
# 73                 27.3             7             3             No
# 49                 32.6             6             2             No
# 44                 38.2             1             6             No
#
#     Years_Played
# 40             8
# 74             8
# 73             8
# 49             8
# 44             9

# %%
df[df['Years_Played']==df['Years_Played'].min()]
# Out:
#      Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 40   BKV Prasad    INDIA             161             160          8129
# 49  Saeed Ajmal      PAK             113             112          6000
# 73   BAW Mendis       SL              87              84          4154
# 74  Rashid Khan      AFG              80              76          4074
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 40           6332            196            32.30          4.67
# 49           4182            184            22.72          4.18
# 73           3324            152            21.86          4.80
# 74           2821            151            18.68          4.15
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 40                 41.4             3             1             No
# 49                 32.6             6             2             No
# 73                 27.3             7             3             No
# 74                 26.9             5             4             No
#
#     Years_Played
# 40             8
# 49             8
# 73             8
# 74             8

# %% [markdown]
# <font color="green"><b>BKV Prasad, Rashid Khan, BAW Mendis and Saeed Ajmal played for the shortest period of time.</b></font>

# %% [markdown]
# #### Q12: How many Australian bowlers are present in this dataset?

# %%
df['Country'].value_counts()
# Out:
# INDIA    13
# PAK      12
# AUS      10
# SL        9
# SA        8
# NZ        8
# ENG       6
# WI        6
# BAN       3
# ZIM       1
# AFG       1
# Name: Country, dtype: int64

# %%
print("Number of Australian bowlers =", df['Country'].value_counts()['AUS'])
# Out:
# Number of Australian bowlers = 10

# %%
df[df['Country']=='AUS']
# Out:
#       Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 6     GD McGrath      AUS             250             248         12970
# 7          B Lee      AUS             221             217         11185
# 13      SK Warne      AUS             194             191         10642
# 28    MG Johnson      AUS             153             150          7489
# 34  CJ McDermott      AUS             138             138          7461
# 41      MA Starc      AUS              99              99          5099
# 42      SR Waugh      AUS             325             207          8883
# 55    NW Bracken      AUS             116             116          5759
# 61     SR Watson      AUS             190             163          6466
# 70       GB Hogg      AUS             123             113          5564
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 6            8391            381            22.02          3.88
# 7            8877            380            23.36          4.76
# 13           7541            293            25.73          4.25
# 28           6038            239            25.26          4.83
# 34           5018            203            24.71          4.03
# 41           4379            195            22.45          5.15
# 42           6761            195            34.67          4.56
# 55           4240            174            24.36          4.41
# 61           5342            168            31.79          4.95
# 70           4188            156            26.84          4.51
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 6                  34.0             9             7            Yes
# 7                  29.4            14             9             No
# 13                 36.3            12             1            Yes
# 28                 31.3             9             3             No
# 34                 36.7             4             1             No
# 41                 26.1            11             8             No
# 42                 45.5             3             0             No
# 55                 33.0             5             2             No
# 61                 38.4             3             0             No
# 70                 35.6             3             2             No
#
#     Years_Played
# 6             15
# 7             13
# 13            13
# 28            11
# 34            12
# 41            12
# 42            17
# 55             9
# 61            14
# 70            13

# %% [markdown]
# #### Q13: Is there any Bangladeshi player present in this dataset?

# %%
df[df['Country'] == 'BAN']
# Out:
#           Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 16   Shakib Al Hasan      BAN             221             218         11351
# 20  Mashrafe Mortaza      BAN             220             220         10922
# 33      Abdur Razzak      BAN             153             152          7965
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 16           8401            285            29.47          4.44
# 20           8893            270            32.93          4.88
# 33           6065            207            29.29          4.56
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 16                 39.8             9             3             No
# 20                 40.4             7             1             No
# 33                 38.4             5             4             No
#
#     Years_Played
# 16            17
# 20            20
# 33            11

# %%
df.loc[df['Country'] == 'BAN']

# %% [markdown]
# <font color="green"><b>There are three Bangladeshi players - Shakib Al Hasan, Mashrafe Mortaza and Abdur Razzak.</b></font>

# %% [markdown]
# #### Q14: Which player had the lowest economy rate?

# %%
df[df['Economy_Rate']==df['Economy_Rate'].min()]
# Out:
#    Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 65  RJ Hadlee       NZ             115             112          6182
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 65           3407            158            21.56           3.3
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 65                 39.1             1             5             No
#
#     Years_Played
# 65            18

# %%
df.sort_values(by='Economy_Rate').head(5)

# %%
df.loc[df['Economy_Rate']==df['Economy_Rate'].min(),'Player_Name']
# Out:
# 65    RJ Hadlee
# Name: Player_Name, dtype: object

# %% [markdown]
# <font color='green'><b>RJ Hadlee has the lowest economy rate.</b></font>

# %% [markdown]
# #### Q15: Which player had the lowest strike rate?

# %%
df.sort_values(by='Bowling_Strike_Rate').head(5)
# Out:
#      Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 41     MA Starc      AUS              99              99          5099
# 74  Rashid Khan      AFG              80              76          4074
# 73   BAW Mendis       SL              87              84          4154
# 7         B Lee      AUS             221             217         11185
# 60     TA Boult       NZ              93              93          5117
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 41           4379            195            22.45          5.15
# 74           2821            151            18.68          4.15
# 73           3324            152            21.86          4.80
# 7            8877            380            23.36          4.76
# 60           4261            169            25.21          4.99
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 41                 26.1            11             8             No
# 74                 26.9             5             4             No
# 73                 27.3             7             3             No
# 7                  29.4            14             9             No
# 60                 30.2             8             5             No
#
#     Years_Played
# 41            12
# 74             8
# 73             8
# 7             13
# 60            10

# %%
df[df['Bowling_Strike_Rate']==df['Bowling_Strike_Rate'].min()]
# Out:
#    Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 41   MA Starc      AUS              99              99          5099
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 41           4379            195            22.45          5.15
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 41                 26.1            11             8             No
#
#     Years_Played
# 41            12

# %% [markdown]
# <font color="green"><b>MA Starc has the lowest bowling strike rate.</b></font>

# %% [markdown]
# #### Q16: Which player had the lowest bowling average?

# %%
df.sort_values(by='Bowling_Average').head(5)
# Out:
#          Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 74      Rashid Khan      AFG              80              76          4074
# 65        RJ Hadlee       NZ             115             112          6182
# 19        AA Donald       SA             164             162          8561
# 14  Saqlain Mushtaq      PAK             169             165          8770
# 73       BAW Mendis       SL              87              84          4154
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 74           2821            151            18.68          4.15
# 65           3407            158            21.56          3.30
# 19           5926            272            21.78          4.15
# 14           6275            288            21.78          4.29
# 73           3324            152            21.86          4.80
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 74                 26.9             5             4             No
# 65                 39.1             1             5             No
# 19                 31.4            11             2             No
# 14                 30.4            11             6             No
# 73                 27.3             7             3             No
#
#     Years_Played
# 74             8
# 65            18
# 19            13
# 14             9
# 73             8

# %%
df[df['Bowling_Average']==df['Bowling_Average'].min()]
# Out:
#      Player_Name Country  Matches_Played  Innings_Bowled  Balls_Bowled  \
# 74  Rashid Khan      AFG              80              76          4074
#
#     Runs_Conceded  Wickets_Taken  Bowling_Average  Economy_Rate  \
# 74           2821            151            18.68          4.15
#
#     Bowling_Strike_Rate  Four_Wickets  Five_Wickets Played_for_ICC  \
# 74                 26.9             5             4             No
#
#     Years_Played
# 74             8

# %% [markdown]
# <font color='green'><b>Rashid Khan has the lowest bowling average.</b></font>

# %% [markdown]
# #### Q17: Remove unnecessary columns if needed

# %%
# Removing the column 'Played_for_ICC'
df = df.drop("Played_for_ICC", axis=1)

display(df.head(5))
